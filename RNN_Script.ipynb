# %%
# !pip install matplotlib_inline
# Out:
# Requirement already satisfied: matplotlib_inline in c:\users\rasimemirdagi\anaconda3\lib\site-packages (0.1.2)
# Requirement already satisfied: traitlets in c:\users\rasimemirdagi\anaconda3\lib\site-packages (from matplotlib_inline) (5.1.0)

# %%
import os

import joblib as jb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch
import torchvision
from d2l import torch as d2l
from torch import nn
from torchmetrics import R2Score
from torchsummary import summary

# %%
class Flatten(nn.Module):
    """Converts N-dimensional tensor into 'flat' one."""

    def __init__(self, keep_batch_dim=True):
        super().__init__()
        self.keep_batch_dim = keep_batch_dim

    def forward(self, x):
        if self.keep_batch_dim:
            return x.view(x.size(0), -1)
        return x.view(-1)

# %%
class RNNRegressor(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(RNNRegressor, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        # Set initial hidden and cell states
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size)

        # Forward propagate LSTM
        out, _ = self.lstm(x, (h0, c0))  # out: tensor of shape (batch_size, seq_length, hidden_size)

        # Decode the hidden state of the last time step
        out = self.fc(out[:, -1, :])
        return out

# %%
# Calculating the loss
# loss = nn.CrossEntropyLoss(reduction='none')
loss = nn.MSELoss(reduction='none')

def evaluate_loss(data_iter, net, devices):
    l_sum, n = 0.0, 0
    for features, labels in data_iter:
        features, labels = features.to(devices[0]), labels.to(devices[0])
        outputs = net(features)
        l = loss(outputs, labels)
        l_sum += l.sum()
        n += labels.numel()
    return l_sum / n

# %%
def loss_plotter(train_losses,test_losses):
    plt.figure(figsize = (10,6) )
    plt.plot(train_losses, 'r*-', label = "Train Loss")
    plt.plot(test_losses, 'b*-', label = "Test Loss")
    plt.legend()
    plt.grid()
    plt.xlabel("Epochs")
    plt.ylabel("The Loss Value")

# %%
spo2_vals = jb.load('strided_dataset_spo2_vals.pk')

# %%
stride_dataset = jb.load('strided_dataset.pk')

# %%
dataset = pd.DataFrame.from_dict(stride_dataset).transpose()

# %%
dataset_spo2 = pd.DataFrame.from_dict(spo2_vals).transpose()

# %%
dataset_spo2 = dataset_spo2/100

# %%
X_train, X_valid, X_test = np.split(dataset.sample(
    frac=1), [int(.8*len(dataset)), int(.9*len(dataset))])
y_train, y_valid, y_test = dataset_spo2.loc[X_train.index], dataset_spo2.loc[
    X_valid.index], dataset_spo2.loc[X_test.index]

# %%
# unroll the data
X_train_unrolled = []
y_train_unrolled = []
for r in X_train.index:
    for c in X_train.columns:
        # skip values containing NaN
        if not np.isnan(X_train.loc[r][c]).any() and not np.isnan(y_train.loc[r][c]):
            X_train_unrolled.append(X_train.loc[r][c])
            y_train_unrolled.append(y_train.loc[r][c])

X_valid_unrolled = []
y_valid_unrolled = []
for r in X_valid.index:
    for c in X_valid.columns:
        # skip values containing NaN
        if not np.isnan(X_valid.loc[r][c]).any() and not np.isnan(y_valid.loc[r][c]):
            X_valid_unrolled.append(X_valid.loc[r][c])
            y_valid_unrolled.append(y_valid.loc[r][c])

X_test_unrolled = []
y_test_unrolled = []
for r in X_test.index:
    for c in X_test.columns:
        # skip values containing NaN
        if not np.isnan(X_test.loc[r][c]).any() and not np.isnan(y_test.loc[r][c]):
            X_test_unrolled.append(X_test.loc[r][c])
            y_test_unrolled.append(y_test.loc[r][c])

# %%
# convert to tensors
X_train, y_train = torch.tensor(X_train_unrolled, dtype=torch.float32), torch.tensor(
    y_train_unrolled, dtype=torch.float32)
X_valid, y_valid = torch.tensor(X_valid_unrolled, dtype=torch.float32), torch.tensor(
    y_valid_unrolled, dtype=torch.float32)
X_test, y_test = torch.tensor(X_test_unrolled, dtype=torch.float32), torch.tensor(
    y_test_unrolled, dtype=torch.float32)
# Out:
# C:\Users\RASIME~1\AppData\Local\Temp/ipykernel_18836/997760739.py:2: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:233.)
#   X_train, y_train = torch.tensor(X_train_unrolled, dtype=torch.float32), torch.tensor(

# %%
# reshape y tensors
y_train = y_train.reshape(-1, 1)
y_valid = y_valid.reshape(-1, 1)
y_test = y_test.reshape(-1, 1)

# %%
# normalize x data
X_train_mean = X_train.mean() 
X_train_std = X_train.std()
X_train = (X_train - X_train_mean) / (X_train_std + 1e-7)

X_valid_mean = X_valid.mean()
X_valid_std = X_valid.std()
X_valid = (X_valid - X_valid_mean) / (X_valid_std + 1e-7)

X_test_mean = X_test.mean()
X_test_std = X_test.std()
X_test = (X_test - X_test_mean) / (X_test_std + 1e-7)

# %%
batch_size = 64
train_iter = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(
    X_train, y_train), batch_size=batch_size, shuffle=True)
valid_iter = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(
    X_valid, y_valid), batch_size=batch_size, shuffle=True)
test_iter = torch.utils.data.DataLoader(torch.utils.data.TensorDataset(
    X_test, y_test), batch_size=batch_size, shuffle=True)

# %%
num_epochs = 10
lr, wd = 0.001, 1e-4
lr_period, lr_decay = 2, 0.9

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
class RNNRegressor(nn.Module):
    def __init__(self, input_size, hidden_size, output_size = 1):
        super(RNNRegressor, self).__init__()
        self.hidden_size = hidden_size
        self.rnn = nn.RNN(input_size, hidden_size, batch_first=True)
        self.fc = nn.Linear(hidden_size, 32)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(32,16)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(16,output_size)
        

    def forward(self, x):
        # Set initial hidden and cell states
        h0 = torch.zeros(1, x.size(0), self.hidden_size)
        
        # Forward propagate the RNN
        out, _ = self.rnn(x, h0)
        
        # Pass the output of the final time step through the fully-connected layer
        out = self.fc(out[:, -1, :])
        out = self.relu1(out)
        out = self.fc2(out)
        out = self.relu2(out)
        out = self.fc3(out)
        return out

# %%
model = RNNRegressor(input_size=240, hidden_size=128).to(device)
#Setting the loss function
cost = nn.L1Loss()

#Setting the optimizer with the model parameters and learning rate
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

#this is defined to print how many steps are remaining when training
total_step = len(train_iter)

# %%
summary(model, input_size = (1,240))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#                RNN-1  [[-1, 1, 128], [-1, 2, 128]]               0
#             Linear-2                   [-1, 32]           4,128
#               ReLU-3                   [-1, 32]               0
#             Linear-4                   [-1, 16]             528
#               ReLU-5                   [-1, 16]               0
#             Linear-6                    [-1, 1]              17
# ================================================================
# Total params: 4,673
# Trainable params: 4,673
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.25
# Params size (MB): 0.02
# Estimated Total Size (MB): 0.27
# ----------------------------------------------------------------

# %%
train_losses = []
test_losses = []

num_epochs = 100
for epoch in range(num_epochs):
    

    
    
    for i, (features, labels) in enumerate(train_iter):
        batch_size = features.shape[0]
        features = torch.reshape(features, (batch_size,1,240))
        labels = torch.reshape(labels, (batch_size,1,1))
        features = features.to(device)
        labels = labels.to(device)
        outputs = model(features)
        loss = cost(outputs, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
        
        
    for i, (features_test, labels_test) in enumerate(test_iter):
        batch_size = features_test.shape[0]
        features_test = torch.reshape(features_test, (batch_size,1,240))
        labels_test = torch.reshape(labels_test, (batch_size,1,1))
        
        features_test = features_test.to(device)
        labels_test = labels_test.to(device)
        outputs_test = model(features_test)
        loss_test = cost(outputs_test,labels_test)
     
    train_losses.append(loss.item()*100)
    test_losses.append(loss_test.item()*100)
    print("1) The Train Loss value with the epoch: " + str(epoch) + " is equal to " + str(loss.item()*100))
    print("2) The Test Loss value with the epoch: " + str(epoch) + " is equal to " + str(loss_test.item()*100))
    print("-------------------------------------------------------------------")
    
    
    if epoch == num_epochs-2:
        jb.dump(train_losses,"train_losses.pk")
        jb.dump(test_losses,"test_losses.pk")
        break
# Out:
# C:\Users\rasimemirdagi\anaconda3\lib\site-packages\torch\nn\modules\loss.py:101: UserWarning: Using a target size (torch.Size([64, 1, 1])) that is different to the input size (torch.Size([64, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.l1_loss(input, target, reduction=self.reduction)
# C:\Users\rasimemirdagi\anaconda3\lib\site-packages\torch\nn\modules\loss.py:101: UserWarning: Using a target size (torch.Size([48, 1, 1])) that is different to the input size (torch.Size([48, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.l1_loss(input, target, reduction=self.reduction)
# C:\Users\rasimemirdagi\anaconda3\lib\site-packages\torch\nn\modules\loss.py:101: UserWarning: Using a target size (torch.Size([16, 1, 1])) that is different to the input size (torch.Size([16, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.l1_loss(input, target, reduction=self.reduction)
# 1) The Train Loss value with the epoch: 0 is equal to 1.9990041851997375
# 2) The Test Loss value with the epoch: 0 is equal to 1.8646789714694023
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 1 is equal to 2.1735893562436104
# 2) The Test Loss value with the epoch: 1 is equal to 1.711743324995041
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 2 is equal to 2.0317507907748222
# 2) The Test Loss value with the epoch: 2 is equal to 1.7866887152194977
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 3 is equal to 1.7215089872479439
# 2) The Test Loss value with the epoch: 3 is equal to 1.798241212964058
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 4 is equal to 2.108648419380188
# 2) The Test Loss value with the epoch: 4 is equal to 1.974502019584179
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 5 is equal to 1.791435293853283
# 2) The Test Loss value with the epoch: 5 is equal to 1.683606207370758
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 6 is equal to 2.0659079775214195
# 2) The Test Loss value with the epoch: 6 is equal to 1.7518088221549988
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 7 is equal to 2.076416090130806
# 2) The Test Loss value with the epoch: 7 is equal to 1.5915405005216599
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 8 is equal to 2.1520821377635
# 2) The Test Loss value with the epoch: 8 is equal to 2.6995308697223663
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 9 is equal to 2.262759394943714
# 2) The Test Loss value with the epoch: 9 is equal to 2.499999850988388
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 10 is equal to 2.0402656868100166
# 2) The Test Loss value with the epoch: 10 is equal to 1.398626621812582
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 11 is equal to 2.2801630198955536
# 2) The Test Loss value with the epoch: 11 is equal to 2.4994492530822754
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 12 is equal to 2.6522688567638397
# 2) The Test Loss value with the epoch: 12 is equal to 1.5452681109309196
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 13 is equal to 1.9915509968996048
# 2) The Test Loss value with the epoch: 13 is equal to 1.6468480229377747
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 14 is equal to 2.522423677146435
# 2) The Test Loss value with the epoch: 14 is equal to 2.5416264310479164
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 15 is equal to 2.4136560037732124
# 2) The Test Loss value with the epoch: 15 is equal to 2.18400489538908
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 16 is equal to 2.342277020215988
# 2) The Test Loss value with the epoch: 16 is equal to 1.7080707475543022
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 17 is equal to 1.6718925908207893
# 2) The Test Loss value with the epoch: 17 is equal to 1.9650615751743317
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 18 is equal to 2.1048424765467644
# 2) The Test Loss value with the epoch: 18 is equal to 2.5000005960464478
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 19 is equal to 2.225254848599434
# 2) The Test Loss value with the epoch: 19 is equal to 1.8042590469121933
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 20 is equal to 2.3263728246092796
# 2) The Test Loss value with the epoch: 20 is equal to 2.3088140413165092
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 21 is equal to 2.050573378801346
# 2) The Test Loss value with the epoch: 21 is equal to 1.132485456764698
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 22 is equal to 2.0298995077610016
# 2) The Test Loss value with the epoch: 22 is equal to 1.6606733202934265
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 23 is equal to 2.205183729529381
# 2) The Test Loss value with the epoch: 23 is equal to 1.532205380499363
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 24 is equal to 2.417071722447872
# 2) The Test Loss value with the epoch: 24 is equal to 1.8535085022449493
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 25 is equal to 2.2554345428943634
# 2) The Test Loss value with the epoch: 25 is equal to 1.4249682426452637
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 26 is equal to 2.468629740178585
# 2) The Test Loss value with the epoch: 26 is equal to 0.9160235524177551
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 27 is equal to 2.300814539194107
# 2) The Test Loss value with the epoch: 27 is equal to 2.813596650958061
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 28 is equal to 1.8701296299695969
# 2) The Test Loss value with the epoch: 28 is equal to 2.1665019914507866
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 29 is equal to 2.2845879197120667
# 2) The Test Loss value with the epoch: 29 is equal to 1.9257009029388428
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 30 is equal to 1.9641740247607231
# 2) The Test Loss value with the epoch: 30 is equal to 1.8225977197289467
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 31 is equal to 1.8389616161584854
# 2) The Test Loss value with the epoch: 31 is equal to 1.9104205071926117
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 32 is equal to 2.162522077560425
# 2) The Test Loss value with the epoch: 32 is equal to 1.8399057909846306
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 33 is equal to 2.045617252588272
# 2) The Test Loss value with the epoch: 33 is equal to 1.5229111537337303
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 34 is equal to 2.1918654441833496
# 2) The Test Loss value with the epoch: 34 is equal to 1.6483793035149574
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 35 is equal to 1.9306225702166557
# 2) The Test Loss value with the epoch: 35 is equal to 2.1628903225064278
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 36 is equal to 2.05793846398592
# 2) The Test Loss value with the epoch: 36 is equal to 2.2712094709277153
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 37 is equal to 1.8984409049153328
# 2) The Test Loss value with the epoch: 37 is equal to 2.0507756620645523
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 38 is equal to 1.8597640097141266
# 2) The Test Loss value with the epoch: 38 is equal to 1.4880340546369553
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 39 is equal to 1.708332821726799
# 2) The Test Loss value with the epoch: 39 is equal to 2.197059988975525
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 40 is equal to 2.0389191806316376
# 2) The Test Loss value with the epoch: 40 is equal to 1.7449039965867996
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 41 is equal to 1.7160682007670403
# 2) The Test Loss value with the epoch: 41 is equal to 1.7965646460652351
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 42 is equal to 1.8490420654416084
# 2) The Test Loss value with the epoch: 42 is equal to 1.6670199111104012
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 43 is equal to 1.9494781270623207
# 2) The Test Loss value with the epoch: 43 is equal to 1.3707784935832024
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 44 is equal to 2.125350199639797
# 2) The Test Loss value with the epoch: 44 is equal to 1.8148167058825493
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 45 is equal to 1.9226055592298508
# 2) The Test Loss value with the epoch: 45 is equal to 2.2031430155038834
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 46 is equal to 1.9096534699201584
# 2) The Test Loss value with the epoch: 46 is equal to 1.916630007326603
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 47 is equal to 2.074340172111988
# 2) The Test Loss value with the epoch: 47 is equal to 1.4623796567320824
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 48 is equal to 2.1119199693202972
# 2) The Test Loss value with the epoch: 48 is equal to 1.025754027068615
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 49 is equal to 2.2759752348065376
# 2) The Test Loss value with the epoch: 49 is equal to 1.6999175772070885
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 50 is equal to 2.188776805996895
# 2) The Test Loss value with the epoch: 50 is equal to 1.528109423816204
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 51 is equal to 1.7581924796104431
# 2) The Test Loss value with the epoch: 51 is equal to 1.560647040605545
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 52 is equal to 1.937500387430191
# 2) The Test Loss value with the epoch: 52 is equal to 1.596011035144329
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 53 is equal to 1.9767606630921364
# 2) The Test Loss value with the epoch: 53 is equal to 1.6888631507754326
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 54 is equal to 1.8796613439917564
# 2) The Test Loss value with the epoch: 54 is equal to 2.2600915282964706
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 55 is equal to 2.38080658018589
# 2) The Test Loss value with the epoch: 55 is equal to 1.3267898932099342
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 56 is equal to 2.196866273880005
# 2) The Test Loss value with the epoch: 56 is equal to 1.7525015398859978
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 57 is equal to 2.5205932557582855
# 2) The Test Loss value with the epoch: 57 is equal to 1.6537625342607498
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 58 is equal to 2.071623131632805
# 2) The Test Loss value with the epoch: 58 is equal to 1.7807269468903542
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 59 is equal to 1.732773333787918
# 2) The Test Loss value with the epoch: 59 is equal to 1.4155412092804909
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 60 is equal to 2.0099079236388206
# 2) The Test Loss value with the epoch: 60 is equal to 1.9553247839212418
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 61 is equal to 2.231111191213131
# 2) The Test Loss value with the epoch: 61 is equal to 2.0625002682209015
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 62 is equal to 1.9029801711440086
# 2) The Test Loss value with the epoch: 62 is equal to 2.0849596709012985
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 63 is equal to 1.8165109679102898
# 2) The Test Loss value with the epoch: 63 is equal to 1.9205942749977112
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 64 is equal to 2.6211757212877274
# 2) The Test Loss value with the epoch: 64 is equal to 1.2782365083694458
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 65 is equal to 2.2158222272992134
# 2) The Test Loss value with the epoch: 65 is equal to 1.7272977158427238
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 66 is equal to 2.4525992572307587
# 2) The Test Loss value with the epoch: 66 is equal to 2.1994460374116898
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 67 is equal to 1.8301088362932205
# 2) The Test Loss value with the epoch: 67 is equal to 2.0413080230355263
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 68 is equal to 2.2294465452432632
# 2) The Test Loss value with the epoch: 68 is equal to 1.7850494012236595
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 69 is equal to 1.8155567348003387
# 2) The Test Loss value with the epoch: 69 is equal to 1.6907081007957458
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 70 is equal to 1.9859187304973602
# 2) The Test Loss value with the epoch: 70 is equal to 2.0732762292027473
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 71 is equal to 2.2251665592193604
# 2) The Test Loss value with the epoch: 71 is equal to 2.359340712428093
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 72 is equal to 2.0369747653603554
# 2) The Test Loss value with the epoch: 72 is equal to 1.684732548892498
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 73 is equal to 1.9020849838852882
# 2) The Test Loss value with the epoch: 73 is equal to 1.3176653534173965
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 74 is equal to 2.440951019525528
# 2) The Test Loss value with the epoch: 74 is equal to 1.941433921456337
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 75 is equal to 2.5046953931450844
# 2) The Test Loss value with the epoch: 75 is equal to 1.3535089790821075
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 76 is equal to 2.0850401371717453
# 2) The Test Loss value with the epoch: 76 is equal to 2.2023458033800125
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 77 is equal to 2.0868467167019844
# 2) The Test Loss value with the epoch: 77 is equal to 1.5075061470270157
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 78 is equal to 2.106582373380661
# 2) The Test Loss value with the epoch: 78 is equal to 1.7577225342392921
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 79 is equal to 2.041666768491268
# 2) The Test Loss value with the epoch: 79 is equal to 1.4112519100308418
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 80 is equal to 2.106584422290325
# 2) The Test Loss value with the epoch: 80 is equal to 2.3840170353651047
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 81 is equal to 1.762544922530651
# 2) The Test Loss value with the epoch: 81 is equal to 1.3622093014419079
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 82 is equal to 2.0090393722057343
# 2) The Test Loss value with the epoch: 82 is equal to 1.562499813735485
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 83 is equal to 2.1866941824555397
# 2) The Test Loss value with the epoch: 83 is equal to 1.290419977158308
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 84 is equal to 1.8427012488245964
# 2) The Test Loss value with the epoch: 84 is equal to 1.4655630104243755
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 85 is equal to 2.2165823727846146
# 2) The Test Loss value with the epoch: 85 is equal to 1.125815510749817
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 86 is equal to 1.903826743364334
# 2) The Test Loss value with the epoch: 86 is equal to 2.4836212396621704
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 87 is equal to 2.086513675749302
# 2) The Test Loss value with the epoch: 87 is equal to 2.26984191685915
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 88 is equal to 1.825827918946743
# 2) The Test Loss value with the epoch: 88 is equal to 1.000136137008667
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 89 is equal to 2.497776225209236
# 2) The Test Loss value with the epoch: 89 is equal to 1.9569193944334984
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 90 is equal to 1.9460109993815422
# 2) The Test Loss value with the epoch: 90 is equal to 1.4209471642971039
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 91 is equal to 2.11783479899168
# 2) The Test Loss value with the epoch: 91 is equal to 2.1255886182188988
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 92 is equal to 2.076924592256546
# 2) The Test Loss value with the epoch: 92 is equal to 2.1076221019029617
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 93 is equal to 2.115839906036854
# 2) The Test Loss value with the epoch: 93 is equal to 2.2068245336413383
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 94 is equal to 2.054358087480068
# 2) The Test Loss value with the epoch: 94 is equal to 0.6466921418905258
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 95 is equal to 2.327282167971134
# 2) The Test Loss value with the epoch: 95 is equal to 1.9766250625252724
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 96 is equal to 2.2391345351934433
# 2) The Test Loss value with the epoch: 96 is equal to 2.4458901956677437
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 97 is equal to 2.070748060941696
# 2) The Test Loss value with the epoch: 97 is equal to 1.527369488030672
# -------------------------------------------------------------------
# 1) The Train Loss value with the epoch: 98 is equal to 2.046618051826954
# 2) The Test Loss value with the epoch: 98 is equal to 1.170018408447504
# -------------------------------------------------------------------
